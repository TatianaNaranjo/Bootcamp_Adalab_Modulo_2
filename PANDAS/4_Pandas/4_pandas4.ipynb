# %% [markdown]
# # 21/04 - Pair Programming Pandas 4 - Tatiana & Lara

# %% [markdown]
# # Ejercicio 1
# Cargad el csv que guardasteis ayer.

# %%
import pandas as pd

datos = pd.read_csv("datos_guardados.csv", index_col= 0)
datos.head(2)
# Out:
#    unnamed:_0 case_number    year        type country        area  \
# 0           0  2018.06.25  2018.0     Boating     USA  California
# 1           1  2018.06.18  2018.0  Unprovoked     USA     Georgia
#
#                          location  activity              name sex_ age  \
# 0     Oceanside, San Diego County  Paddling       Julie Wolfe    F  57
# 1  St. Simon Island, Glynn County  Standing  AdysonÂ McNeely     F  11
#
#             time     species_  \
# 0          18h00  White shark
# 1  14h00  -15h00          NaN
#
#                                                 href
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...

# %% [markdown]
# # Ejercicio 2
# ¿Cuál es el número de ataques que se han producido en Estados Unidos?

# %%
datos.columns
estados_unidos = datos[datos["country"]=="USA"]
ataques_usa = estados_unidos.shape[0]
print ("El número de ataques en USA fue : ", ataques_usa)
# Out:
# El número de ataques en USA fue :  2200

# %% [markdown]
# # Ejercicio 3
# ¿Cuál es el número de ataques que se han producido en España?

# %%
españa = datos[datos["country"]=="SPAIN"]
ataques_españa = españa.shape[0]
print ("El número de ataques en España fue : ", ataques_españa)
# Out:
# El número de ataques en España fue :  42

# %% [markdown]
# ¿En qué regiones de España se han producido los ataques?
# ¿Cuántos ataques se han producido en cada área de España?

# %%
regiones_españa = españa["area"].unique()
print("1. En estas regiones de España se han producido ataques: ", regiones_españa, "\n")

ataques_regiones_españa = españa["area"].value_counts()
print("2. Este es el número de ataques que se han producido en las distintas regiones de España, sin tener en cuenta errores de escritura (aparecen diferenciados):", ataques_regiones_españa)
# Out:
# 1. En estas regiones de España se han producido ataques:  ['Canary Islands' 'CastellÃ³n' 'Majorca' 'Ibiza Island'
#  'Alicante Province' 'Grand Canary Island' 'Alicante' 'Granada'
#  'Catalonia' 'Catalunya' 'Costa Blanca' 'CÃ¡diz' 'Valencia'
#  'Sants-Montjic' 'Valencia ' 'Galica' 'Gran Canaria' 'Balearics'
#  'MÃ¡laga ' 'Andalucia' 'Galicia' 'Eastern Catalona' nan 'Malaga']
#
# 2. Este es el número de ataques que se han producido en las distintas regiones de España, sin tener en cuenta errores de escritura (aparecen diferenciados): Canary Islands         7
# Catalonia              4
# Alicante               3
# CÃ¡diz                 3
# Malaga                 2
# Valencia               2
# Grand Canary Island    2
# Galica                 1
# Eastern Catalona       1
# Galicia                1
# Andalucia              1
# MÃ¡laga                1
# Balearics              1
# Gran Canaria           1
# Alicante Province      1
# Valencia               1
# CastellÃ³n             1
# ...

# %% [markdown]
# # Ejercicio 4
#
# Extraed un DataFrame nuevo con los ataques que se han producido en Australia y Estados Unidos.
#
# 📌 Nota Este ejercicio se puede resolver usando dos condiciones de filtrado o usando el método isin(). Hacedlo con ambas herramientas.

# %%
#Filtrado

df = datos[(datos['country'] == "USA") | (datos["country"] == "AUSTRALIA")]
df.head()
# Out:
#    unnamed:_0   case_number    year        type    country             area  \
# 0           0    2018.06.25  2018.0     Boating        USA       California
# 1           1    2018.06.18  2018.0  Unprovoked        USA          Georgia
# 2           2    2018.06.09  2018.0     Invalid        USA           Hawaii
# 3           3    2018.06.08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 5           5  2018.06.03.b  2018.0  Unprovoked  AUSTRALIA  New South Wales
#
#                          location      activity              name sex_  age  \
# 0     Oceanside, San Diego County      Paddling       Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County      Standing  AdysonÂ McNeely     F   11
# 2                    Habush, Oahu       Surfing       John Denges    M   48
# 3              Arrawarra Headland       Surfing              male    M  NaN
# 5              Flat Rock, Ballina  Kite surfing          Chris Â
#     M  NaN
#
#             time     species_  \
# ...

# %%
#Método insin()

df_usaaus = datos[datos["country"].isin(["AUSTRALIA","USA"])]
df_usaaus.head()
# Out:
#    unnamed:_0   case_number    year        type    country             area  \
# 0           0    2018.06.25  2018.0     Boating        USA       California
# 1           1    2018.06.18  2018.0  Unprovoked        USA          Georgia
# 2           2    2018.06.09  2018.0     Invalid        USA           Hawaii
# 3           3    2018.06.08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 5           5  2018.06.03.b  2018.0  Unprovoked  AUSTRALIA  New South Wales
#
#                          location      activity              name sex_  age  \
# 0     Oceanside, San Diego County      Paddling       Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County      Standing  AdysonÂ McNeely     F   11
# 2                    Habush, Oahu       Surfing       John Denges    M   48
# 3              Arrawarra Headland       Surfing              male    M  NaN
# 5              Flat Rock, Ballina  Kite surfing          Chris Â
#     M  NaN
#
#             time     species_  \
# ...

# %% [markdown]
# 4.1 ¿Cuántos ataques se han producido en cada pais?

# %%
ataques_usa2 = (df["country"] == "USA").sum()
ataques_aus = (df["country"] == "AUSTRALIA").sum()
print("En USA se han producido", ataques_usa2, "ataques. Y en Australia se han producido", ataques_aus)
# Out:
# En USA se han producido 2200 ataques. Y en Australia se han producido 1316

# %% [markdown]
# 4.2 ¿Ha habido ataques en Australia a gente que estuviera remando (lo encontrareis como Paddling en el DataFrame en la columna activity)?

# %%
paddle_attacks = df[(df["country"] == "AUSTRALIA") & (df["activity"] == "Paddling")]

print("En el siguiente data frame encontramos la información del único ataque registrado en Australia a una persona que realizaba paddling:")
paddle_attacks
# Out:
# En el siguiente data frame encontramos la información del único ataque registrado en Australia a una persona que realizaba paddling:
#       unnamed:_0 case_number    year  type    country        area  \
# 4022        4034  1959.12.29  1959.0  Boat  AUSTRALIA  Queensland
#
#                  location  activity  \
# 4022  Scotts Point Beach   Paddling
#
#                                                 name sex_  age       time  \
# 4022  12' ski, occupants: Bill Dyer & Cliff Burgess   NaN  NaN  Afternoon
#
#                      species_  \
# 4022  3.7 m [12'] tiger shark
#
#                                                    href
# 4022  http://sharkattackfile.net/spreadsheets/pdf_di...

# %% [markdown]
# 4.3 ¿Cuántos ataques se han producido en Australia antes del 2000?

# %%
attacks_bf2000 = df[(df["country"] == "AUSTRALIA") & (df["year"] < 2000)]
print("Este es el número de ataques producidos en Australia antes del año 2000:",
attacks_bf2000.shape[0])
# Out:
# Este es el número de ataques producidos en Australia antes del año 2000: 921

# %% [markdown]
# 4.4 ¿Y después del 2000?

# %%
attacks_af2000 = df[(df["country"] == "AUSTRALIA") & (df["year"] > 2000)]
print("Este es el número de ataques producidos en Australia después del año 2000:",
attacks_af2000.shape[0])
# Out:
# Este es el número de ataques producidos en Australia después del año 2000: 377

# %% [markdown]
# # Ejercicio 5
# Extraed unicamente los ataques a mujeres.

# %%
attacks_on_women = df[df["sex_"] == "F"]
attacks_on_women.head()
# Out:
#     unnamed:_0 case_number    year        type    country               area  \
# 0            0  2018.06.25  2018.0     Boating        USA         California
# 1            1  2018.06.18  2018.0  Unprovoked        USA            Georgia
# 14          14  2018.05.00  2018.0    Provoked  AUSTRALIA  Westerm Australia
# 40          40  2018.02.23  2018.0  Unprovoked  AUSTRALIA    New South Wales
# 43          43  2018.02.14  2018.0     Invalid  AUSTRALIA         Queensland
#
#                               location        activity              name sex_  \
# 0          Oceanside, San Diego County        Paddling       Julie Wolfe    F
# 1       St. Simon Island, Glynn County        Standing  AdysonÂ McNeely     F
# 14                          Dugong Bay  Feeding sharks   Melisa Brunning    F
# 40  Little Congwong Beach, La Perouse         Swimming    Anna Shurapey     F
# 43                    Mooloolaba Beach        Swimming       Sharna Babd    F
#
# ...

# %% [markdown]
# # Ejercicio 6
#  ¿Cuántas mujeres fueron atacadas en España?

# %%
attacks_on_women_spa = españa[españa["sex_"] == "F"]
print("El número de mujeres atacadas en España es de", attacks_on_women_spa.shape[0])
# Out:
# El número de mujeres atacadas en España es de 9

# %% [markdown]
# # Ejercicio 7
# Extraed los ataques que se hayan producido en el año 2000, 1997 y 2006. Utilizad el método isin() para resolver este ejercicio.

# %%
_2000_97_06 = df[df["year"].isin([2000, 1997, 2006])]

_2000_97_06.sample(6)
# Out:
#       unnamed:_0   case_number    year        type    country  \
# 1441        1447  2006.08.00.b  2006.0  Unprovoked        USA
# 2062        2069    2000.03.02  2000.0  Unprovoked  AUSTRALIA
# 2021        2028    2000.07.25  2000.0  Unprovoked        USA
# 1491        1497    2006.03.15  2006.0  Unprovoked  AUSTRALIA
# 2063        2070    2000.03.00  2000.0  Unprovoked        USA
# 1450        1456  2006.07.17.R  2006.0     Invalid  AUSTRALIA
#
#                  area                                 location      activity  \
# 1441   North Carolina     Masonboro Island, New Hanover County        Wading
# 2062  New South Wales  Taronga Wharf, Athol Bay, Sydney Harbor      Swimming
# 2021          Florida         New Smyrna Beach, Volusia County           NaN
# 1491  New South Wales                            Bondi, Sydney       Surfing
# 2063        Louisiana        Midnight Lump (38 miles offshore)  Spearfishing
# ...

# %% [markdown]
# # Ejercicio 8
#
# Si extraemos los valores únicos de la columna species nos podemos dar cuenta que está un poco sucia y extraer informacion útil de la misma. En este ejercicio tendréis que extraer los ataques que han ocurrido por tiburón blanco (lo encontraremos en la columna species como algo que contenga white o White). Usad el método str.contains() para resolver este ejercicio.

# %%
df["species_"].unique()
# Out:
# array(['White shark', nan, '2 m shark', "Lemon shark, 3'",
#        "Bull shark, 6'", 'Grey reef shark', 'Tawny nurse shark, 2m',
#        'Shark involvement not confirmed', 'Questionable', '3 m shark',
#        'White shark, 3.5 m', "6' shark", "Tiger shark, 12'",
#        'Wobbegong shark', '3.5 m shark', '1.8 m shark',
#        'Juvenile white shark,  2.7 to 3.2 m', 'Bull shark, 2 m',
#        'Possibly a wobbegong', '2m shark', 'Bull shark',
#        'Grey reef shark. 2 m', 'Wobbegong shark?', 'Tiger shark',
#        'White shark, 4.6 m', 'Cookiecutter shark', 'Wobbegong shark, 1 m',
#        'White shark, 4.5 m', 'Spinner shark, 4 to 5 feet',
#        'Tiger shark, 8 to 10 feet', "8' shark", "5' shark",
#        "4' to 5' shark", 'White shark, 3.5m', "5' to 6' shark",
#        'White shark, 3 to 3.5m ', 'Nurse shark', 'White shark, 3 m',
#        "White shark, 5' to 7'", 'Possibly a juvenile blacktip shark',
#        "4' shark", "White shark, 10'", 'A small shark',
# ...

# %%
patron = "[W|w]hite]"

df_sin_na = df.dropna()

white_shark_attacks = df_sin_na[df_sin_na["species_"].str.contains(patron, regex= True)]
white_shark_attacks.head(10)
# Out:
#      unnamed:_0   case_number    year        type    country  \
# 0             0    2018.06.25  2018.0     Boating        USA
# 40           40    2018.02.23  2018.0  Unprovoked  AUSTRALIA
# 60           60    2017.11.24  2017.0  Unprovoked        USA
# 71           71    2017.10.22  2017.0  Unprovoked  AUSTRALIA
# 89           89  2017.09.10.a  2017.0  Unprovoked  AUSTRALIA
# 96           96    2017.08.29  2017.0  Unprovoked  AUSTRALIA
# 100         100    2017.08.23  2017.0  Unprovoked        USA
# 116         116  2017.07.20.b  2017.0     Boating        USA
# 117         117  2017.07.20.a  2017.0  Unprovoked        USA
# 133         133    2017.06.11  2017.0  Unprovoked  AUSTRALIA
#
#                   area                                     location  \
# 0           California                  Oceanside, San Diego County
# 40     New South Wales           Little Congwong Beach, La Perouse
# 60          California             Stillwater Cove, Monterey County
# ...

# %% [markdown]
# # Ejercicio 9
# Extraed ahora los ataques por tiburón blanco o tigre. Utilizad el método str.contains() para resolver este ejercicio.

# %%
patron2 = "[W|w][hite]|[T|t][iger]]"

white_tiger_shark_attacks = df_sin_na[df_sin_na["species_"].str.contains(patron2, regex= True)]
white_tiger_shark_attacks.sample(3)
# Out:
#      unnamed:_0   case_number    year        type    country             area  \
# 756         760  2012.07.30.a  2012.0  Unprovoked        USA    Massachusetts
# 40           40    2018.02.23  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 831         835    2011.12.11  2011.0  Unprovoked  AUSTRALIA  New South Wales
#
#                                location      activity            name sex_  \
# 756     Ballston Beach, Truro, Cape Cod  Body surfing     Chris Myers    M
# 40   Little Congwong Beach, La Perouse       Swimming  Anna Shurapey     F
# 831                            Angourie       Surfing      Steve King    M
#
#     age         time                             species_  \
# 756  50        15h30     Thought to involve a white shark
# 40   55  19h00, Dusk  Juvenile white shark,  2.7 to 3.2 m
# 831  51        05h45                    White shark, 2.5m
#
#                                                   href
# 756  http://sharkattackfile.net/spreadsheets/pdf_di...
# ...

# %% [markdown]
# # Ejercicio 10
# Utilizando la columna de year cread una nueva columna llamada siglo que tiene siglo-XX o siglo-XXI. Donde el año sea menor que 2000 pondremos siglo-XX y el resto de los años siglo-XXI.

# %%
import numpy as np

# %%
df_copia = df.copy()
df_copia["siglo"] = np.where(df_copia["year"] >= 2000, "siglo XXI", "siglo XX")
df_copia
# Out:
#       unnamed:_0   case_number    year          type    country  \
# 0              0    2018.06.25  2018.0       Boating        USA
# 1              1    2018.06.18  2018.0    Unprovoked        USA
# 2              2    2018.06.09  2018.0       Invalid        USA
# 3              3    2018.06.08  2018.0    Unprovoked  AUSTRALIA
# 5              5  2018.06.03.b  2018.0    Unprovoked  AUSTRALIA
# ...          ...           ...     ...           ...        ...
# 6107        6125    1806.04.24  1896.0  Sea Disaster        USA
# 6108        6126    1805.09.00  1805.0       Invalid        USA
# 6109        6127  1804.02.26.R  1804.0          Boat  AUSTRALIA
# 6110        6128    1803.05.17  1803.0  Sea Disaster        USA
# 6111        6129    1803.03.00  1803.0    Unprovoked  AUSTRALIA
#
#                    area                          location      activity  \
# 0            California       Oceanside, San Diego County      Paddling
# ...
